# %%
import boto3
import cv2
import numpy as np
import json
import boto3
import requests
import numpy as np
import cv2
from matplotlib import pyplot as plt
import sagemaker
import matplotlib.pyplot as plt
from sagemaker.tensorflow.model import TensorFlowModel 
import requests 

bucket='bucketname' 

def load_image(s3key):
    s3 = boto3.resource('s3')
    myobject = s3.Object(bucket,s3key)
    content=myobject.get()['Body'].read()
    nparr = np.frombuffer(content, np.uint8)
    img_np = cv2.imdecode(nparr, cv2.IMREAD_COLOR) 
    width = 300
    height = int(300*(img_np.shape[0]/img_np.shape[1]))
    dim = (width, height)
    
    resized = cv2.resize(img_np, dim, interpolation = cv2.INTER_AREA)
    RGB_img = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img, interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show() 
    image_np_expanded=np.expand_dims(RGB_img, axis=0)
    return image_np_expanded 


def predict_object(s3key):
    session = boto3.session.Session(region_name='eu-west-2')
    sagemaker_session = sagemaker.Session(boto_session=session)
    np_array=load_image(s3key)
    endpoint_name='sagemaker-tensorflow-xxxxxxxxxxxxxxxx'
    predictor=sagemaker.tensorflow.model.TensorFlowPredictor(endpoint_name, sagemaker_session)
    result=predictor.predict(np_array)
    brand=result['outputs']['detection_classes']['float_val'][0]
    score=result['outputs']['detection_scores']['float_val'][0]
    if brand==1:
        return {'brand':'brand_name','probability':score}
    else:
        return {'brand':'brand_name2','probability':score} 


def predict_object_url(url):
    r=requests.get(url)
    if r.status_code!=200:
        raise Exception('requests error,status_code:{}'.format(r.status_code))
        
    content=r.content
    session = boto3.session.Session(region_name='eu-west-2')
    sagemaker_session = sagemaker.Session(boto_session=session)
    nparr = np.frombuffer(content, np.uint8)
    img_np = cv2.imdecode(nparr, cv2.IMREAD_COLOR) 
    width = 300
    height = int(300*(img_np.shape[0]/img_np.shape[1]))
    dim = (width, height) # resize image
    
    resized = cv2.resize(img_np, dim, interpolation = cv2.INTER_AREA)
    RGB_img = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img, interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.axis('off') 
    plt.show() 
    
    image_np_expanded=np.expand_dims(RGB_img, axis=0) 
    #deploy a new api endpoint in the sagemaker 
    endpoint_name='sagemaker-tensorflow-xxxxxxxxxxxxxxxx'
    predictor=sagemaker.tensorflow.model.TensorFlowPredictor(endpoint_name, sagemaker_session)
    result=predictor.predict(image_np_expanded)
    brand=result['outputs']['detection_classes']['float_val'][0]
    score=result['outputs']['detection_scores']['float_val'][0]
    if brand==1:
        return {'brand':'coca-cola','probability':score}
    else:
        return {'brand':'pepsi','probability':score}  
    
import pandas as pd
import numpy as np 

import pymysql
import json
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import event
import pandas.io.sql as psql

#sample
host="rds-mysql-aunz.cn8zi5k8bzi2.us-east-1.rds.amazonaws.com"
user="user"
passwd="password"
db='db'
engine = create_engine("mysql+pymysql://"+user+':'+passwd+"@"+host+"/"+db+'?charset=utf8mb4') 

sql1 = '''SELECT * FROM DataCenter.meal_image; '''

meal_img= psql.read_sql(sql1,engine) 
print(meal_img.shape) 
meal_img[:10]
# Out:
# (247666, 7)
#                               id_source  \
# 0  00032d28-6f94-311f-8779-448d7c43aa56
# 1  00032d28-6f94-311f-8779-448d7c43aa56
# 2  00032d28-6f94-311f-8779-448d7c43aa56
# 3  00032d28-6f94-311f-8779-448d7c43aa56
# 4  00032d28-6f94-311f-8779-448d7c43aa56
# 5  00032d28-6f94-311f-8779-448d7c43aa56
# 6  000e2857-cd99-3a95-960c-8f502f6f7ae2
# 7  000e2857-cd99-3a95-960c-8f502f6f7ae2
# 8  000e2857-cd99-3a95-960c-8f502f6f7ae2
# 9  000e2857-cd99-3a95-960c-8f502f6f7ae2
#
#                                            image_url     source  \
# 0  http://f.roocdn.com/images/menu_items/10846441...  deliveroo
# 1  http://f.roocdn.com/images/menu_items/10847185...  deliveroo
# 2  http://f.roocdn.com/images/menu_items/10846435...  deliveroo
# 3  http://f.roocdn.com/images/menu_items/10846986...  deliveroo
# 4  http://f.roocdn.com/images/menu_items/10846555...  deliveroo
# 5  http://f.roocdn.com/images/menu_items/10846343...  deliveroo
# 6  http://f.roocdn.com/images/menu_items/6280892/...  deliveroo
# 7  http://f.roocdn.com/images/menu_items/6280843/...  deliveroo
# 8  http://f.roocdn.com/images/menu_items/6280873/...  deliveroo
# 9  http://f.roocdn.com/images/menu_items/6280864/...  deliveroo
#
#                                                s3key         bucketname  \
# 0  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 1  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 2  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 3  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 4  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 5  food_image/deliveroo/00032d28-6f94-311f-8779-4...  dash-datapipeline
# 6  food_image/deliveroo/000e2857-cd99-3a95-960c-8...  dash-datapipeline
# 7  food_image/deliveroo/000e2857-cd99-3a95-960c-8...  dash-datapipeline
# 8  food_image/deliveroo/000e2857-cd99-3a95-960c-8...  dash-datapipeline
# 9  food_image/deliveroo/000e2857-cd99-3a95-960c-8...  dash-datapipeline
#
#          last_refresh          created_at
# 0 2019-05-27 03:12:37 2019-05-27 03:12:37
# 1 2019-05-27 03:12:41 2019-05-27 03:12:41
# 2 2019-05-27 03:12:38 2019-05-27 03:12:38
# 3 2019-05-27 03:12:37 2019-05-27 03:12:37
# 4 2019-05-27 03:12:39 2019-05-27 03:12:39
# 5 2019-05-27 03:12:38 2019-05-27 03:12:38
# 6 2019-05-27 03:12:42 2019-05-27 03:12:42
# 7 2019-05-27 03:12:34 2019-05-27 03:12:34
# 8 2019-05-27 03:12:41 2019-05-27 03:12:41
# 9 2019-05-27 03:12:41 2019-05-27 03:12:41

# %%
def show_img():
    for i in meal_img['s3key'][820:860:2]:
        result= predict_cocacola(i)
        print(result) 
    
show_img()
# Out:
# {'brand': 'coca-cola', 'probability': 0.0012991521507501602}
# {'brand': 'pepsi', 'probability': 0.125639870762825}
# {'brand': 'pepsi', 'probability': 0.02047654800117016}
# {'brand': 'coca-cola', 'probability': 0.004371456801891327}
# {'brand': 'pepsi', 'probability': 0.01008921954780817}
# {'brand': 'coca-cola', 'probability': 0.010077172890305519}
# {'brand': 'pepsi', 'probability': 0.518740177154541}
# {'brand': 'coca-cola', 'probability': 0.0036850960459560156}
# {'brand': 'coca-cola', 'probability': 0.006186027079820633}
# {'brand': 'pepsi', 'probability': 0.006192374043166637}
# {'brand': 'pepsi', 'probability': 0.0027600598987191916}
# {'brand': 'pepsi', 'probability': 0.0011823418317362666}
# {'brand': 'pepsi', 'probability': 0.002406339393928647}
# {'brand': 'pepsi', 'probability': 0.00181457435246557}
# {'brand': 'pepsi', 'probability': 0.017994705587625504}
# {'brand': 'pepsi', 'probability': 0.02150953747332096}
# {'brand': 'coca-cola', 'probability': 0.005940480623394251}
# {'brand': 'pepsi', 'probability': 0.011308618821203709}
# {'brand': 'pepsi', 'probability': 0.0032327810768038034}
